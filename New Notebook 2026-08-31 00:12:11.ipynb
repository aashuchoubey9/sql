# %%
# %sql
DROP TABLE IF EXISTS Employees;
DROP TABLE IF EXISTS Departments;
DROP TABLE IF EXISTS Projects;

# %%
# %sql
CREATE TABLE Departments (
    department_id INT PRIMARY KEY,
    department_name VARCHAR(50)
);

INSERT INTO Departments (department_id, department_name) VALUES
(101, 'Engineering'),
(102, 'Data Science'),
(103, 'Human Resources');

# %%
# %sql
CREATE TABLE Employees (
    employee_id INT PRIMARY KEY,
    first_name VARCHAR(50),
    last_name VARCHAR(50),
    department_id INT,
    hire_date DATE,
    job_title VARCHAR(50),
    salary DECIMAL(10,2),
    FOREIGN KEY (department_id) REFERENCES Departments(department_id)
);

# %%
# %sql
INSERT INTO Employees VALUES
(1, 'John', 'Smith', 101, '2018-03-15', 'Software Engineer', 60000, 5),
(2, 'Sarah', 'Johnson', 102, '2019-07-01', 'Data Analyst', 55000, 6),
(3, 'Michael', 'Brown', 101, '2017-11-20', 'Senior Engineer', 80000, 5),
(4, 'Emily', 'Davis', 103, '2020-05-18', 'HR Specialist', 50000, 7),
(5, 'David', 'Wilson', 101, '2015-01-10', 'Engineering Mgr', 95000, NULL),
(6, 'Linda', 'Martinez', 102, '2016-02-25', 'Data Science Mgr', 105000, NULL),
(7, 'James', 'Anderson', 103, '2014-09-12', 'HR Manager', 90000, NULL),
(8, 'Robert', 'Taylor', 101, '2021-08-09', 'Intern', 30000, 5);

# %%
# %sql
CREATE TABLE Projects (
    project_id INT PRIMARY KEY,
    project_name VARCHAR(100),
    department_id INT,
    budget DECIMAL(10,2),
    start_date DATE,
    end_date DATE,
    FOREIGN KEY (department_id) REFERENCES Departments(department_id)
);

INSERT INTO Projects VALUES
(201, 'AI Chatbot', 102, 200000, '2021-01-01', '2021-12-31'),
(202, 'Mobile App', 101, 150000, '2020-06-01', '2021-06-01'),
(203, 'Recruitment Drive', 103, 80000, '2021-03-01', '2021-09-01'),
(204, 'Cloud Migration', 101, 300000, '2019-04-01', '2022-04-01');

# %%
# %sql
select * from employees;

# %%
# %sql
select * from departments;

# %%
# %sql
select * from projects;

# %%
# %sql
select * from employees where department_id = 101;

# %%
# %sql
select first_name from employees where hire_date > '2018-12-31';

# %%
# %sql
select first_name, salary from employees where salary > 70000;

# %%
# %sql
select distinct job_title from employees;

# %%
# %sql
select first_name, last_name, hire_date from employees order by hire_date asc;

# %%
# %sql
select d.department_name, d.department_id, round(avg(e.salary), 2) as avg_salary from employees e
join departments d on e.department_id = d.department_id group by d.department_name, d.department_id;

# %%
# %sql
select e.first_name, d.department_name
from employees e
join departments d
on e.department_id = d.department_id;

# %%
# %sql
select e.first_name, d.department_name, e.salary
from employees e
join departments d
on e.department_id = d.department_id
where d.department_name = 'Data Science'
order by e.salary desc limit 1;

# %%
# %sql
select * from employees where department_id = 102 order by salary desc limit 1;

# %%
# %sql
select manager_id, count(*) as num_manager from employees where manager_id is not null group by manager_id;

# %%
# %sql
select e.first_name, e.last_name, e.department_id, p.project_name, p.budget
from employees e
join projects p
on e.department_id = p.department_id
where budget > 200000;

# %%
# %sql
select first_name, last_name, salary from employees where salary >
(select avg(salary) from employees);

# %%
# %sql
select count(e.employee_id) as emp_count, e.department_id, d.department_name
from employees e
join departments d
on e.department_id = d.department_id
group by e.department_id, d.department_name
having count(e.employee_id) > 2;

# %%
# %sql
select * from employees where manager_id is NULL;

# %%
# %sql
select employee_id, first_name, last_name
from employees
where employee_id not in (select distinct manager_id from employees where manager_id is not null);

# %%
# %sql
select first_name, last_name from employees where department_id not in (select department_id from projects);

# %%
# %sql
select max(salary) from employees where salary < (select max(salary) from employees)

# %%
# %sql
select e.first_name, e.salary, d.department_name,
RANK() OVER (PARTITION BY e.department_id ORDER BY e.salary DESC) AS salary_rank
from employees e
join departments d
on e.department_id = d.department_id;

# %%
# %sql
select * from employees order by salary desc limit 3;

# %%
# %sql
SELECT first_name, hire_date, salary,
SUM(salary) OVER (ORDER BY hire_date) AS cumulative_salary
FROM employees
ORDER BY hire_date;

# %%
# %sql
select d.department_name, avg(e.salary) as avg_salary
from employees e
join departments d 
on e.department_id = d.department_id
group by d.department_name
having avg(e.salary) > (select avg(salary) from employees)
order by avg_salary desc;

# %%
# %sql
select e.first_name, e.manager_id, m.first_name
from employees e
left join employees m
on e.manager_id = m.employee_id;

# %%
# %sql
select d.department_name, sum(e.salary) as total_salary
from employees e
join departments d
on e.department_id = d.department_id
group by d.department_name;

# %%
# %sql
select first_name, last_name, hire_date from employees where hire_date like "2020%";

# %%
# %sql
select first_name from employees where first_name like "J%"

# %%
# %sql
select first_name, last_name, salary from employees where salary between 50000 and 90000;

# %%
# %sql
select d.department_name, count(p.project_id)
from departments d
join projects p
on d.department_id = p.department_id
group by d.department_name;

# %%
# %sql
select project_name, end_date from projects where end_date < "2021-01-01";
SELECT project_name, end_date FROM projects WHERE YEAR(end_date) < "2021";

# %%
# %sql
select e.first_name, e.hire_date, m.first_name, m.hire_date
from employees e
join employees m
on e.manager_id = m.employee_id
where e.hire_date < m.hire_date;

# %%
# %sql
select d.department_name, min(e.salary) as min_salary, max(e.salary) as max_salary
from employees e 
join departments d
on e.department_id = d.department_id
group by department_name;

# %%
# %sql
SELECT job_title, COUNT(*) AS count FROM Employees GROUP BY job_title HAVING COUNT(*) > 1;

# %%
# %sql
select first_name, last_name, hire_date from employees where hire_date >= current_date() - INTERVAL 3 YEAR

# %%
# %sql
select e.first_name, e.last_name, p.project_name, p.start_date
from employees e 
join projects p 
on e.department_id = p.department_id
where year(p.start_date) = '2021';

# %%
# %sql
select e.first_name, e.salary, m.first_name, m.salary 
from employees e
join employees m  
on e.manager_id = m.employee_id
where m.salary < e.salary;

# %%
# %sql
select d.department_name, p.project_name
from departments d
join projects p
on d.department_id = p.department_id
where p.project_name is NULL;

# %%
# %sql
select e.first_name, e.last_name, count(p.project_id) as projectCount
from employees e
join projects p 
on e.department_id = p.department_id
group by e.employee_id, e.first_name, e.last_name
having count(p.project_id) > 1;

# %%
# %sql
select e.first_name, e.last_name, e.salary, d.department_name
from employees e
join departments d
on e.department_id = d.department_id
where e.salary = (select avg(salary) from employees where d.department_id = e.department_id);

# %%
# %sql
select budget, project_name from projects order by budget desc limit 1;

# %%
# %sql
select e.first_name, e.last_name, e.salary, d.department_name
from employees e
join departments d
on e.department_id = d.department_id
where e.salary = (select max(salary) from employees where department_id = d.department_id)

# %%
# %sql
select e.first_name, e.hire_date, m.first_name, m.hire_date
from employees e
join employees m
on e.manager_id = m.employee_id
where year(e.hire_date) = year(m.hire_date);

# %%
# %sql
SELECT YEAR(start_date) AS year, round(AVG(budget), 2) AS avg_budget
FROM Projects
GROUP BY YEAR(start_date);

# %%
# %sql
select e.first_name, e.last_name,
    CASE
        WHEN m.employee_id IS NOT NULL THEN 'Manager'
        ELSE 'Not a Manager'
    END AS manager_status
from employees e
join employees m 
on e.manager_id = m.employee_id;

# %%
# %sql
select project_name, start_date, end_date, datediff(end_date, start_date) as duration
from projects
order by duration desc;

# %%
# %sql
select d.department_id, round(avg(e.salary), 2) as avg_salary
from employees e
join departments d
on e.department_id = d.department_id
group by d.department_id
order by avg(e.salary) desc;

# %%
# %sql
select e.first_name, e.salary, m.first_name, m.salary
from employees e 
join employees m 
on e.manager_id = m.employee_id
where e.salary > m.salary;

# %%
# %sql
select project_name, start_date, end_date from projects where end_date IS NULL;

# %%
# %sql
SELECT YEAR(hire_date) AS year, SUM(salary) AS total_salary
FROM Employees
GROUP BY YEAR(hire_date)
ORDER BY year;

# %%
# %sql
select max(salary) - min(salary) from employees;

# %%
# %sql
select first_name, salary, 
rank() over (order by salary desc) as rank_in_company
from employees;

# %%
# %sql
select e.first_name, d.department_name, e.hire_date
from employees e 
join departments d
on e.department_id = d.department_id
order by d.department_name, e.hire_date;

# %%
# %sql
select project_name, budget from projects order by budget asc limit 1;

# %%
# %sql
select e.first_name, e.last_name, e.salary, d.department_name
from employees e
join departments d
on e.department_id = d.department_id
where e.salary > (select avg(salary) from employees where department_id = d.department_id);

# %% [markdown]
# END of SQL part 1
